# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data0 = pd.read_csv("diabetes.csv")

data0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data0.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# We can observe that our dataset has 9 columns that includes 8 features and target column 'Outcome'.
# Also all features are numeric type.

# %% [markdown]
# ## Data Exploration

# %%
data0.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %% [markdown]
# The data has no missing values but some missing values have been made 0. This can be concluded as many columns has minimum value as 0.
# No living person can have zero insulin or blood pressure at 0, and neither can their BMI. So we will have to replace these values with some more appropriate ones.

# %%
# We are gonna replace the 0 with random value around the mean with standard Deviation of 1.2 (+/-)

for col in ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]:
    mean = data0[data0[col] != 0][col].mean()
    std = data0[data0[col] != 0][col].std()

    values = data0[col].values

    np.random.seed(23)

    for i, val in enumerate(values):
        if val == 0:
            values[i] = mean + std * (np.random.rand() * 2 - 1) * 1.2
    data0[col] = pd.Series(values).astype(data0[col].dtype)

# %%
data0.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.705729      72.371094      28.907552  152.865885
# std       3.369578   30.481394      12.249431       9.632385  102.668104
# min       0.000000   44.000000      24.000000       7.000000   13.000000
# 25%       1.000000   99.750000      64.000000      22.000000   77.000000
# 50%       3.000000  117.000000      72.000000      29.000000  134.500000
# 75%       6.000000  141.000000      80.000000      36.000000  205.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.446890                  0.471876   33.240885    0.348958
# std      6.896638                  0.331329   11.760232    0.476951
# ...

# %%
data1 = data0.copy()

# %%
fig, axs = plt.subplots(4, 2, figsize=(30, 35))
ax = axs.flatten()
for i, col in enumerate(data1.columns.drop("Outcome")):
    #ax = axs[i // 2][i % 2]

    #kde(df, col, ax, color=color, meanline_color=color)
    sns.distplot(data1[col], ax=ax[i],kde= True )
    #ax.set_xlabel(col)
    ax[i].set_title(col)

fig.suptitle("Distribution of numeric columns", fontsize=30, y=0.90)

plt.show()
# Out:
# C:\Users\akshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\akshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# From that graph we can see:
#
#  1.  "Pregnancies", "Insulin", "DiabetesPedigreeFunction" and "Age" have a right-skewed distribution.
#  2.  In contrast, "Glucose," "BloodPressure," "SkinThickness" and "BMI" have a normal distribution.
#  3.  We can see that the ages of our patients ranged from just over 10 to even 90 years old, showing a very high range of age.

# %%
plt.figure(figsize=(15, 8))

sns.countplot(x="Outcome", data=data1)

plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(30, 35))

for i, col in enumerate(data1.columns.drop("Outcome")):
    ax = axs[i // 2][i % 2]

    sns.kdeplot(data=data1, x=col, ax=ax,
        fill=True, linewidth=2, hue="Outcome")
    #kde(df, col, ax, hue="Outcome", hue_colors=hue_dict)
    ax.set_xlabel(col, fontsize="xx-large")

fig.suptitle("Distribution of numeric columns by Outcome", fontsize=30, y=0.90)

plt.show()

# %% [markdown]
# From the graph we note that patients with diagnosed diabetes tend to have higher values for all available features.
# This is especially true for "Glucose" and "BMI," where both the distribution and the mean of the two classes differ the most.
#
# In terms of age, the difference between the two classes is also very high.
#
# It is also interesting to note that having more pregnancies correlates with a higher likelihood of being diagnosed with diabetes.

# %%
sns.scatterplot(data=data1, x = "BMI", y = "BloodPressure", hue="Outcome", linewidth=1, edgecolor='black', alpha=0.7)
plt.show()
sns.scatterplot(data=data1, x = "Insulin", y = "Glucose", hue="Outcome", linewidth=1, edgecolor='black', alpha=0.7)
plt.show()
sns.scatterplot(data=data1, x = "DiabetesPedigreeFunction", y = "Age", hue="Outcome", linewidth=1, edgecolor='black', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12,9))
sns.heatmap(data1.corr(),vmax=.8, square =True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# With a value of 0.49, the highest correlation with "Outcome" is with "Glucose." This is followed, as we noted from the previous graphs, by "BMI" and "Age"

# %% [markdown]
# ## Spliting the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = data1.drop("Outcome", axis=1)
y = data1["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %% [markdown]
# ## Searching for baseline model

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV

from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

# %%
def cv_and_evaluate(model, X_train, y_train, X_test, y_test, name=None):

    cv_score = cross_val_score(model, X_train, y_train, cv=4, n_jobs=-1)
    
    print(f"{name} CV Results \t Mean: {np.mean(cv_score)} \t Std: {np.std(cv_score)}")
    print(cv_score)

    model.fit(X_train, y_train)

    y_test_pred = model.predict(X_test)
    
#     try:
#         y_test_score = model.predict_proba(X_test)[:, 1]
#     except:
#         y_test_score = model.decision_function(X_test)

    #classifier_evaluation(y_test, y_test_pred, y_test_score)
    
    accuracy = accuracy_score(y_test, y_test_pred)
    precision = precision_score(y_test, y_test_pred)
    recall  = recall_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred)
    
    print("Accuracy = ", np.round(accuracy,2))
    print("Precision = ", np.round(precision,2))
    print("Recall = ", np.round(recall,2))
    print("F1 = ", np.round(f1,2))

# %%
# Adaboost

base = DecisionTreeClassifier(random_state=23, max_depth=3)
adb_clf = AdaBoostClassifier(base, random_state=23, n_estimators=50)

cv_and_evaluate(adb_clf, X_train, y_train, X_test, y_test, name="AdaBoost")
# Out:
# AdaBoost CV Results 	 Mean: 0.6970758000169764 	 Std: 0.0269978448007715
# [0.67532468 0.71428571 0.66666667 0.73202614]
# Accuracy =  0.81
# Precision =  0.71
# Recall =  0.77
# F1 =  0.74

# %%
# Logistic regression

lr = LogisticRegression()

cv_and_evaluate(lr, X_train_scaled, y_train, X_test_scaled, y_test, name="LogisticRegression")
# Out:
# LogisticRegression CV Results 	 Mean: 0.7621912401324166 	 Std: 0.02298083988045996
# [0.74025974 0.7987013  0.76470588 0.74509804]
# Accuracy =  0.79
# Precision =  0.71
# Recall =  0.66
# F1 =  0.69

# %%
# RandomForest

rf = RandomForestClassifier(max_depth=8, random_state=23)

cv_and_evaluate(rf, X_train, y_train, X_test, y_test, name="Random Forest")
# Out:
# Random Forest CV Results 	 Mean: 0.7263708513708514 	 Std: 0.016806973878124833
# [0.71428571 0.74675325 0.73856209 0.70588235]
# Accuracy =  0.81
# Precision =  0.73
# Recall =  0.72
# F1 =  0.72

# %%
#SVC

svc = SVC(probability=True, random_state=23)

cv_and_evaluate(svc, X_train_scaled, y_train, X_test_scaled, y_test, name="SVC")
# Out:
# SVC CV Results 	 Mean: 0.7248005262711145 	 Std: 0.01606786587547987
# [0.7012987  0.72077922 0.73202614 0.74509804]
# Accuracy =  0.81
# Precision =  0.74
# Recall =  0.66
# F1 =  0.7

# %% [markdown]
# The results are very similar to each other.
# We are choosing SVC as the model with which to proceed. SVM allow good tuning, and having little data they perform very well, both in time factor and metrics

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# We will use different kernel to see if there is any difference.

# %%
model = SVC(kernel="poly", degree=3, random_state=23)

cv_and_evaluate(model, X_train_scaled, y_train, X_test_scaled, y_test, name="SVC Poly")
# Out:
# SVC Poly CV Results 	 Mean: 0.7133626177743825 	 Std: 0.01360975395634518
# [0.69480519 0.72727273 0.7254902  0.70588235]
# Accuracy =  0.75
# Precision =  0.7
# Recall =  0.49
# F1 =  0.58

# %%
model = SVC(kernel="linear", random_state=23)

cv_and_evaluate(model, X_train_scaled, y_train, X_test_scaled, y_test, name="SVC Linear")
# Out:
# SVC Linear CV Results 	 Mean: 0.7573317205670147 	 Std: 0.02118935766410867
# [0.72727273 0.78571429 0.76470588 0.75163399]
# Accuracy =  0.81
# Precision =  0.73
# Recall =  0.68
# F1 =  0.71

# %% [markdown]
# Looking at the results, we are keeping the default kernel.
# In fact, having to diagnose a disease, it is more important for our model to score a higher recall score, even at the cost of giving up some precision.

# %%
model = SVC(probability=True, random_state=23)

params_grid = {
    "gamma": [0.1, 1, 10, 100],
    "C": [0.1, 1, 10, 100, 1000]
}

svc_gridsearch = GridSearchCV(model, params_grid, n_jobs=-1)

svc_gridsearch.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True, random_state=23), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [0.1, 1, 10, 100]})

# %%
print("Best params: \t", svc_gridsearch.best_params_)
print("Best Score: \t", svc_gridsearch.best_score_)
# Out:
# Best params: 	 {'C': 1, 'gamma': 0.1}
# Best Score: 	 0.7394109023057445

# %%
model = svc_gridsearch.best_estimator_

cv_and_evaluate(model, X_train_scaled, y_train, X_test_scaled, y_test, name="SVC tuned")
# Out:
# SVC tuned CV Results 	 Mean: 0.7296812664459723 	 Std: 0.014155192386791205
# [0.70779221 0.72727273 0.74509804 0.73856209]
# Accuracy =  0.82
# Precision =  0.76
# Recall =  0.7
# F1 =  0.73

# %% [markdown]
# There is no much difference even after applying hyperparameter.

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# We will selecting only important features for better results.

# %%
from sklearn.inspection import permutation_importance

importances = pd.Series(permutation_importance(model, X_test_scaled, y_test, random_state=23).importances_mean, 
                        index=X_test.columns)

importances.sort_values(ascending=False, inplace=True)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(x=importances.values, y=importances.index, ax=ax, linewidth=2, edgecolor="black")

ax.set_xlabel("Permutation Importance")
ax.set_title("Feature Importances - SVC")

sns.despine(ax=ax, left=True, bottom=False)
ax.grid(axis="y", linewidth=0.2, color="black")
#set_style(ax, axis_grid="x", bottom=True)

plt.show()

# %% [markdown]
# In this notebook we carried out in-depth data exploration, making the best use of data visualization.
# We also cleaned the data, replacing null values with more probable ones, without losing any training instances.
# Later, after finding a promising model, we optimized it. To achieve even better performance, we finally oversampled the minority class, and selected the best features.
#
# The results are not the best possible, and this is due to the small amount of data available. By having more training instances available most likely our model could have had much better results.
